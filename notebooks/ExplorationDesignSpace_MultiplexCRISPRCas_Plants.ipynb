# %% [markdown]
# # Exploring the design space of combinatorial CRISPR experiments

# %% [markdown]
# ## 1. Load packages

# %%
import Pkg; Pkg.add(url="https://github.com/kirstvh/MultiplexCrisprDOE")

# %%
using Random; Random.seed!(1234) # Set a seed for reproducibility
using Plots 
using Distributions 
using Combinatorics
using BioCCP
using MultiplexCrisprDOE

# %% [markdown]
# ### Illustration

# %%
n_gRNA_pergene = 6
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false)
# Out:
# 1

# %%
n_gRNA_perconstruct = 1
simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# (111.912, 37.493356205053665)

# %%
BioCCP_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global)
# Out:
# (113, 39)

# %%
n_gRNA_perconstruct = 2
simulate_RES2(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
# (2924.65, 694.2425837054803)

# %% [markdown]
# ## 2. Explore impact of design parameters

# %% [markdown]
# ### 2.1 RES1

# %% [markdown]
# #### 2.1.1 Number of target genes

# %%
### N = 10
n_targets = 10
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_10_sim_single, sd_10_sim_single = simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_10_bioccp_single, sd_10_bioccp_single = BioCCP_RES1(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 20
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_20_sim_single, sd_20_sim_single = simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_20_bioccp_single, sd_20_bioccp_single = BioCCP_RES1(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 30
n_targets = 30
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_30_sim_single, sd_30_sim_single = simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_30_bioccp_single, sd_30_bioccp_single = BioCCP_RES1(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 40
n_targets = 40
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_40_sim_single, sd_40_sim_single = simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_40_bioccp_single, sd_40_bioccp_single = BioCCP_RES1(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 50
n_targets = 50
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_50_sim_single, sd_50_sim_single = simulate_RES1(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_50_bioccp_single, sd_50_bioccp_single = BioCCP_RES1(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)
# Out:
# (352, 100)

# %%
E_targets_sim_single = [E_10_sim_single, E_20_sim_single, E_30_sim_single, E_40_sim_single, E_50_sim_single]
E_targets_bioccp_single = [E_10_bioccp_single, E_20_bioccp_single, E_30_bioccp_single, E_40_bioccp_single, E_50_bioccp_single]
sd_targets_sim_single = [sd_10_sim_single, sd_20_sim_single, sd_30_sim_single, sd_40_sim_single, sd_50_sim_single]
sd_targets_bioccp_single = [sd_10_bioccp_single, sd_20_bioccp_single, sd_30_bioccp_single, sd_40_bioccp_single, sd_50_bioccp_single];

# %%
plot(collect(10:10:50), E_targets_sim_single, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all single KOs
    ", xlabel="Number of target genes", ylabel="Required experimental scale",
    ribbon = sd_targets_sim_single, fillalpha=.1,
    xticks = (10:10:50, string.(10:10:50)),
    yticks = (100:100:600, string.(100:100:600)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!(collect(10:10:50), E_targets_bioccp_single,  label="BioCCP",
    ribbon = sd_targets_bioccp_single, 
    fillalpha=.1,
)

# %% [markdown]
# #### 2.1.2 gRNA frequency distribution

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 1
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

# %%
## 0
Random.seed!(80)
m= 300
sd= 0  
l = 200
u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
maximum(p_gRNA_lib)/minimum(p_gRNA_lib)


E_p1_bioccp_single, sd_p1_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p1_sim_single, sd_p1_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

##10
Random.seed!(80)
sd=  1000 #0 #175
l = 50
u = 500
m= 300
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)

E_p10_bioccp_single, sd_p10_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p10_sim_single, sd_p10_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

##100
Random.seed!(80)
sd=  1000 #0 #175
l = 43
u = 5000
m= 300
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)

E_p100_bioccp_single, sd_p100_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p100_sim_single, sd_p100_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# (186.136, 80.17809275054023)

# %%
E_p_sim_single = [E_p1_sim_single, E_p10_sim_single, E_p100_sim_single]
E_p_bioccp_single = [E_p1_bioccp_single, E_p10_bioccp_single, E_p100_bioccp_single]
sd_p_sim_single = [sd_p1_sim_single, sd_p10_sim_single, sd_p100_sim_single]
sd_p_bioccp_single = [sd_p1_bioccp_single, sd_p10_bioccp_single, sd_p100_bioccp_single]
# Out:
# 3-element Array{Int64,1}:
#  44
#  52
#  80

# %%
plot([1, 10, 100], E_p_sim_single, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all single gene KO
    ", xlabel="(pmax/mpin)", ylabel="Required experimental scale",
    ribbon = sd_p_sim_single, fillalpha=.1,
    xticks = ([1, 10, 100], string.([1, 10, 100])),
    yticks = (0:50:300, string.(0:50:300)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101, xaxis=:log, 
 )

plot!([1, 10, 100], E_p_bioccp_single,  label="BioCCP",
    ribbon = sd_p_bioccp_single, 
    fillalpha=.1,
)

scatter!([1], [50], label="", markersize=0.00000001)

# %% [markdown]
# ####  2.1.4 Fraction active gRNAs

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 1
ϵ_knockout_global = 0.8
Random.seed!(80)
m= 300; sd= 175; l = 200; u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true);

# %%
## 10
Random.seed!(80)
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;


E_p_inact10_bioccp_single, sd_p_inact10_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact10_sim_single, sd_p_inact10_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 20
Random.seed!(80)
p_active = 0.8; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

E_p_inact20_bioccp_single, sd_p_inact20_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact20_sim_single, sd_p_inact20_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 30
Random.seed!(80)
p_active = 0.7; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

E_p_inact30_bioccp_single, sd_p_inact30_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact30_sim_single, sd_p_inact30_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# (182.444, 91.64687208150998)

# %%
E_p_inact_sim_single = [E_p_inact10_sim_single, E_p_inact20_sim_single, E_p_inact30_sim_single]
E_p_inact_bioccp_single = [E_p_inact10_bioccp_single, E_p_inact20_bioccp_single, E_p_inact30_bioccp_single]
sd_p_inact_sim_single = [sd_p_inact10_sim_single, sd_p_inact20_sim_single, sd_p_inact30_sim_single]
sd_p_inact_bioccp_single = [sd_p_inact10_bioccp_single, sd_p_inact20_bioccp_single, sd_p_inact30_bioccp_single]
# Out:
# 3-element Array{Int64,1}:
#  45
#  53
#  82

# %%
plot([0.7, 0.8, 0.9], [E_p_inact30_sim_single, E_p_inact20_sim_single, E_p_inact10_sim_single], label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all single gene KOs
    ", xlabel="Fraction active gRNAs", ylabel="Required experimental scale",
    ribbon = [sd_p_inact30_sim_single, sd_p_inact20_sim_single, sd_p_inact10_sim_single], fillalpha=.1,
    xticks = ([0.7, 0.8, 0.9], string.([0.7, 0.8, 0.9])),
    yticks = (50:50:300, string.(50:50:300)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!([0.7, 0.8, 0.9], [E_p_inact30_bioccp_single, E_p_inact20_bioccp_single, E_p_inact10_bioccp_single],  label="BioCCP",
    ribbon = [sd_p_inact30_bioccp_single, sd_p_inact20_bioccp_single, sd_p_inact10_bioccp_single], 
    fillalpha=.1,
)

scatter!([0.7], [30], markersize=0.00001, label="")

# %% [markdown]
# #### 2.1.4 KNOCKOUT EFFICIENCY

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 1
Random.seed!(80)
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;
m= 300; sd= 175; l = 200; u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true);

# %%
## 70
ϵ_knockout_global = 0.7

E_p_KO70_bioccp_single, sd_p_KO70_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO70_sim_single, sd_p_KO70_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 80
ϵ_knockout_global = 0.8

E_p_KO80_bioccp_single, sd_p_KO80_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO80_sim_single, sd_p_KO80_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 90
ϵ_knockout_global = 0.9

E_p_KO90_bioccp_single, sd_p_KO90_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO90_sim_single, sd_p_KO90_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
## 100
ϵ_knockout_global = 1

E_p_KO100_bioccp_single, sd_p_KO100_bioccp_single = BioCCP_minsamplesize_single(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO100_sim_single, sd_p_KO100_sim_single = simulate_minsamplesize_single(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# (90.786, 31.829710412283983)

# %%
E_p_KO_sim_single = [E_p_KO70_sim_single, E_p_KO80_sim_single, E_p_KO90_sim_single,E_p_KO100_sim_single]
E_p_KO_bioccp_single = [E_p_KO70_bioccp_single, E_p_KO80_bioccp_single, E_p_KO90_bioccp_single, E_p_KO100_bioccp_single]
sd_p_KO_sim_single = [sd_p_KO70_sim_single, sd_p_KO80_sim_single, sd_p_KO90_sim_single,sd_p_KO100_sim_single]
sd_p_KO_bioccp_single = [sd_p_KO70_bioccp_single, sd_p_KO80_bioccp_single, sd_p_KO90_bioccp_single, sd_p_KO100_bioccp_single]
# Out:
# 4-element Array{Int64,1}:
#  48
#  42
#  37
#  34

# %%
plot([0.7, 0.8, 0.9, 1], E_p_KO_sim_single, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all single gene KOs
    ", xlabel="KO efficiency", ylabel="Required experimental scale",
    ribbon = sd_p_KO_sim_single, fillalpha=.1,
    xticks = ([0.7, 0.8, 0.9, 1], string.([0.7, 0.8, 0.9, 1])),
    yticks = (0:50:300, string.(0:50:300)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!([0.7, 0.8, 0.9, 1], E_p_KO_bioccp_single,  label="BioCCP",
    ribbon = sd_p_KO_bioccp_single, 
    fillalpha=.1,
)

scatter!([0.7], [30], label="", markersize=0.00001)

# %% [markdown]
# ### 2.2 RES2

# %%
n_gRNA_pergene = 6
n_gRNA_perconstruct = 2
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
# Out:
# 0.01

# %%
### N = 10
n_targets = 10
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

# E_10_sim, sd_10_sim = simulate_minsamplesize_pairwise(n_targets, 
#                                 n_gRNA_pergene, 
#                                 n_gRNA_perconstruct, 
#                                 n_gRNA_total, 
#                                 p_gRNA_library, 
#                                 p_gRNA_act, ϵ_knockout_global; iter=500)

E_10_bioccp, sd_10_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 20
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_20_sim, sd_20_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_20_bioccp, sd_20_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 30
n_targets = 30
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_30_sim, sd_30_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_30_bioccp, sd_30_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 40
n_targets = 40
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_40_sim, sd_40_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_40_bioccp, sd_40_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 50
n_targets = 50
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_50_sim, sd_50_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

E_50_bioccp, sd_50_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

# %%
E_targets_sim = [E_10_sim, E_20_sim, E_30_sim, E_40_sim, E_50_sim]
E_targets_bioccp = [E_10_bioccp, E_20_bioccp, E_30_bioccp, E_40_bioccp, E_50_bioccp]
sd_targets_sim = [sd_10_sim, sd_20_sim, sd_30_sim, sd_40_sim, sd_50_sim]
sd_targets_bioccp = [sd_10_bioccp, sd_20_bioccp, sd_30_bioccp, sd_40_bioccp, sd_50_bioccp];

# %%
plot(collect(10:10:50), E_targets_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="Number of target genes", ylabel="Required experimental scale",
    ribbon = sd_targets_sim, fillalpha=.1,
    xticks = (10:10:50, string.(10:10:50)),
    yticks = (0:10000:50000, string.(0:10000:50000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!(collect(10:10:50), E_targets_bioccp,  label="BioCCP",
    ribbon = sd_targets_bioccp, 
    fillalpha=.1,
)

# %% [markdown]
# #### 2.2.2 gRNA frequency distribution

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 2
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

# %%
## 0
Random.seed!(80)
m= 300
sd= 0  
l = 200
u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
maximum(p_gRNA_lib)/minimum(p_gRNA_lib)


E_p1_bioccp, sd_p1_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p1_sim, sd_p1_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

##10
Random.seed!(80)
sd=  1000 #0 #175
l = 50
u = 500
m= 300
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)

E_p10_bioccp, sd_p10_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p10_sim, sd_p10_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

##100
Random.seed!(80)
sd=  1000 #0 #175
l = 43
u = 5000
m= 300
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)

E_p100_bioccp, sd_p100_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p100_sim, sd_p100_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
# (16372.51, 7983.631346251257)

# %%
E_p_sim = [E_p1_sim, E_p10_sim, E_p100_sim]
E_p_bioccp = [E_p1_bioccp, E_p10_bioccp, E_p100_bioccp]
sd_p_sim = [sd_p1_sim, sd_p10_sim, sd_p100_sim]
sd_p_bioccp = [sd_p1_bioccp, sd_p10_bioccp, sd_p100_bioccp]
# Out:
# 3-element Array{Int64,1}:
#   830
#  2212
#  6645

# %%
plot([1, 10, 100], E_p_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="(pmax/mpin)", ylabel="Required experimental scale",
    ribbon = sd_p_sim, fillalpha=.1,
    xticks = ([1, 10, 100], string.([1, 10, 100])),
    yticks = (0:5000:25000, string.(0:5000:25000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101, xaxis=:log)

plot!([1, 10, 100], E_p_bioccp,  label="BioCCP",
    ribbon = sd_p_bioccp, 
    fillalpha=.1,
)

# %%
##2
Random.seed!(80)
m= 300
sd = 250 #0 #175
l = 200
u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)

histogram(p_gRNA_lib)

BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)# histogram(p_gRNA_lib, bins=20)
# Out:
# (3512, 1049)

# %%
histogram(p_gRNA_lib)

# %% [markdown]
# #### 2.2.3 Percentage active gRNAs

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 2
ϵ_knockout_global = 0.8
Random.seed!(80)
m= 300; sd= 175; l = 200; u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true);

# %%
## 10
Random.seed!(80)
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;


E_p_inact10_bioccp, sd_p_inact10_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact10_sim, sd_p_inact10_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 20
Random.seed!(80)
p_active = 0.8; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

E_p_inact20_bioccp, sd_p_inact20_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact20_sim, sd_p_inact20_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 30
Random.seed!(80)
p_active = 0.7; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;

E_p_inact30_bioccp, sd_p_inact30_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_inact30_sim, sd_p_inact30_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
# (8495.454, 2763.8000726476466)

# %%
E_p_inact_sim = [E_p_inact10_sim, E_p_inact20_sim, E_p_inact30_sim]
E_p_inact_bioccp = [E_p_inact10_bioccp, E_p_inact20_bioccp, E_p_inact30_bioccp]
sd_p_inact_sim = [sd_p_inact10_sim, sd_p_inact20_sim, sd_p_inact30_sim]
sd_p_inact_bioccp = [sd_p_inact10_bioccp, sd_p_inact20_bioccp, sd_p_inact30_bioccp]
# Out:
# 3-element Array{Int64,1}:
#   929
#  1282
#  3070

# %%
plot([0.7, 0.8, 0.9], [E_p_inact30_sim, E_p_inact20_sim, E_p_inact10_sim], label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="Fraction active gRNAs", ylabel="Required experimental scale",
    ribbon = [sd_p_inact30_sim, sd_p_inact20_sim, sd_p_inact10_sim], fillalpha=.1,
    xticks = ([0.7, 0.8, 0.9], string.([0.7, 0.8, 0.9])),
    yticks = (3000:2000:11000, string.(3000:2000:11000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!([0.7, 0.8, 0.9], [E_p_inact30_bioccp, E_p_inact20_bioccp, E_p_inact10_bioccp],  label="BioCCP",
    ribbon = [sd_p_inact30_bioccp, sd_p_inact20_bioccp, sd_p_inact10_bioccp], 
    fillalpha=.1,
)

# %% [markdown]
# #### 2.2.5 knockout efficiency

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene
n_gRNA_perconstruct = 2
Random.seed!(80)
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;
m= 300; sd= 175; l = 200; u = 400
p_gRNA_lib = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true);

# %%
## 70
ϵ_knockout_global = 0.7

E_p_KO70_bioccp, sd_p_KO70_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO70_sim, sd_p_KO70_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 80
ϵ_knockout_global = 0.8

E_p_KO80_bioccp, sd_p_KO80_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO80_sim, sd_p_KO80_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 90
ϵ_knockout_global = 0.9

E_p_KO90_bioccp, sd_p_KO90_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO90_sim, sd_p_KO90_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
## 100
ϵ_knockout_global = 1

E_p_KO100_bioccp, sd_p_KO100_bioccp = BioCCP_minsamplesize_pairwise(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_p_KO100_sim, sd_p_KO100_sim = simulate_minsamplesize_pairwise(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
# (2006.254, 563.6831511352345)

# %%
E_p_KO_sim = [E_p_KO70_sim, E_p_KO80_sim, E_p_KO90_sim,E_p_KO100_sim]
E_p_KO_bioccp = [E_p_KO70_bioccp, E_p_KO80_bioccp, E_p_KO90_bioccp, E_p_KO100_bioccp]
sd_p_KO_sim = [sd_p_KO70_sim, sd_p_KO80_sim, sd_p_KO90_sim,sd_p_KO100_sim]
sd_p_KO_bioccp = [sd_p_KO70_bioccp, sd_p_KO80_bioccp, sd_p_KO90_bioccp, sd_p_KO100_bioccp]
# Out:
# 4-element Array{Int64,1}:
#  1060
#   818
#   639
#   527

# %%
plot([0.7, 0.8, 0.9, 1], E_p_KO_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="KO efficiency", ylabel="Required experimental scale",
    ribbon = sd_p_KO_sim, fillalpha=.1,
    xticks = ([0.7, 0.8, 0.9, 1], string.([0.7, 0.8, 0.9, 1])),
    yticks = (1000:1000:11000, string.(1000:1000:11000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!([0.7, 0.8, 0.9, 1], E_p_KO_bioccp,  label="BioCCP",
    ribbon = sd_p_KO_bioccp, 
    fillalpha=.1,
)

# %% [markdown]
# ### 2.3 Success probability P_S

# %%
n_gRNA_pergene = 6
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false)


sample_sizes = 0:10:6000
p_success_pairwise = []
p_success_single = []

for sample_size in sample_sizes
    n_gRNA_perconstruct = 2
    push!(p_success_pairwise, BioCCP_success_probability_pairwise(n_targets, sample_size,
                                         n_gRNA_pergene, 
                                         n_gRNA_perconstruct, 
                                         n_gRNA_total, 
                                         p_gRNA_library, 
                                         p_gRNA_act, ϵ_knockout_global))
    
    n_gRNA_perconstruct = 1
    push!(p_success_single, BioCCP_success_probability_single(n_targets, sample_size,
                                         n_gRNA_pergene, 
                                         n_gRNA_perconstruct, 
                                         n_gRNA_total, 
                                         p_gRNA_library, 
                                         p_gRNA_act, ϵ_knockout_global))
end
 
plot(sample_sizes, p_success_single, label="P_(single gene KOs)
    ")

plot!(sample_sizes, p_success_pairwise,
label="P_(pairwise combinations of gene KOs)", title="Success probability 
    ",
xlabel="n° plants", ylabel="success probability", 
        xticks = (0:500:50000, string.(0:500:50000)),
 size=(900,400))
hline!([0.95], linestyle=:dash, color=:grey, label="P_ = 95%", legend=:bottomright)

# %% [markdown]
# ### 2.4 Expected represented fraction of the design space E_f

# %%
n_gRNA_pergene = 6
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_library_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false)


sample_sizes = 0:10:4000
expected_fraction_pairwise = []
expected_fraction_single = []


for sample_size in sample_sizes
    n_gRNA_perconstruct = 2
    push!(expected_fraction_pairwise, BioCCP_expected_fraction_pairwise(n_targets, sample_size,
                                         n_gRNA_pergene, 
                                         n_gRNA_perconstruct, 
                                         n_gRNA_total, 
                                         p_gRNA_library, 
                                         p_gRNA_act, ϵ_knockout_global))
    
    n_gRNA_perconstruct = 1
    push!(expected_fraction_single, BioCCP_expected_fraction_single(n_targets, sample_size,
                                         n_gRNA_pergene, 
                                         n_gRNA_perconstruct, 
                                         n_gRNA_total, 
                                         p_gRNA_library, 
                                         p_gRNA_act, ϵ_knockout_global))
end
 
plot(sample_sizes, expected_fraction_single, label="E_f(single gene KOs)
    ")

plot!(sample_sizes, expected_fraction_pairwise,
label="E_f(pairwise combinations of gene KOs)", title="expected_fraction 
    ",
xlabel="n° plants", ylabel="expected_fraction", 
        xticks = (0:500:50000, string.(0:500:50000)),
 size=(900,400))
hline!([0.95], linestyle=:dash, color=:grey, label="E_f = 95%", legend=:bottomright)

# %% [markdown]
# ### 2.4 Split - Select - Combine & Overshoot - Select - Purify approach

# %% [markdown]
# ##### Splitting

# %% [markdown]
# RES2

# %%
E_split_sim = [E_40_sim, 2*E_20_sim, 4*E_10_sim]
E_split_bioccp = [E_40_bioccp, 2*E_20_bioccp, 4*E_10_bioccp]
sd_split_sim = [sd_40_sim, sd_20_sim, sd_10_sim]
sd_split_bioccp = [sd_40_bioccp, sd_20_bioccp, sd_10_bioccp];

# %%
plot([40, 20, 10], E_split_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="Size of gene subset", ylabel="Required experimental scale",
    ribbon = sd_split_sim, fillalpha=.1,
    xticks = ([40, 20, 10], string.([40, 20, 10])),
    yticks = (2000:2000:17000, string.(2000:2000:17000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)


plot!(collect([40, 20, 10]), E_split_bioccp,  label="BioCCP",
    ribbon = sd_split_bioccp, 
    fillalpha=.1,
    xflip=true
)


plot!([40, 20, 10], E_split_sim,  label="", xaxis=:log10, linestyle = :dot, linealpha = 0.5,
    seriestype = :steppre, linecolor = :black)

scatter!([40, 20, 10], [E_40_sim, E_20_sim, E_10_sim],markersize = 5, markercolor = :orange, 
    label="Gene subset", markershape = :square,     markerstrokecolor = :orange,
)
scatter!([40, 20, 10], [E_40_sim, 2*E_20_sim, 4*E_10_sim],markersize = 4, markercolor = :black, label="Total gene set")

# %% [markdown]
# RES3

# %%
n_gRNA_pergene = 6
n_gRNA_perconstruct = 3
ϵ_knockout_global = 0.8
m= 300; sd= 175; l = 200; u = 400
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01

# %%
### N = 10
n_targets = 10
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_10_sim, sd_10_sim = simulate_RES3(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=100)

E_10_bioccp, sd_10_bioccp = BioCCP_RES3(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)

### N = 20
n_targets = 20
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_20_sim, sd_20_sim = simulate_RES3(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=100)

E_20_bioccp, sd_20_bioccp = BioCCP_RES3(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)


### N = 40
n_targets = 40
n_gRNA_total = n_targets * n_gRNA_pergene
Random.seed!(80)
p_gRNA_library = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true)
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) 

E_40_sim, sd_40_sim = simulate_RES3(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_library, 
                                p_gRNA_act, ϵ_knockout_global; iter=100)

E_40_bioccp, sd_40_bioccp = BioCCP_RES3(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_library, 
                              p_gRNA_act, ϵ_knockout_global)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...

# %%
E_split_sim = [E_40_sim, 2*E_20_sim, 4*E_10_sim]
E_split_bioccp = [E_40_bioccp, 2*E_20_bioccp, 4*E_10_bioccp]
sd_split_sim = [sd_40_sim, sd_20_sim, sd_10_sim]
sd_split_bioccp = [sd_40_bioccp, sd_20_bioccp, sd_10_bioccp]

plot([40, 20, 10], E_split_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all triple combinations
    ", xlabel="Size of gene subset", ylabel="Required experimental scale",
    ribbon = sd_split_sim, fillalpha=.1,
    xticks = ([40, 20, 10], string.([40, 20, 10])),
    yticks = (2000:2000:17000, string.(2000:2000:17000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)


plot!(collect([40, 20, 10]), E_split_bioccp,  label="BioCCP",
    ribbon = sd_split_bioccp, 
    fillalpha=.1,
    xflip=true
)


plot!([40, 20, 10], E_split_sim,  label="", xaxis=:log10, linestyle = :dot, linealpha = 0.5,
    seriestype = :steppre, linecolor = :black)

scatter!([40, 20, 10], [E_40_sim, E_20_sim, E_10_sim],markersize = 5, markercolor = :orange, 
    label="Gene subset", markershape = :square,     markerstrokecolor = :orange,
)
scatter!([40, 20, 10], [E_40_sim, 2*E_20_sim, 4*E_10_sim],markersize = 4, markercolor = :black, label="Total gene set")

# %% [markdown]
# ##### overshooting

# %%
n_targets = 20
n_gRNA_pergene = 6
n_gRNA_total= n_targets * n_gRNA_pergene

Random.seed!(80)
p_active = 0.9; high_activity = 0.9; low_activity = 0.1; sd = 0.01
p_gRNA_act = gRNA_activity_distribution(p_active, high_activity, low_activity, sd, n_gRNA_total; visualize=false) ;
m= 300; sd= 175; l = 200; u = 400
p_gRNA_lib = gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize=true);
ϵ_knockout_global = 0.8
# Out:
# 0.8

# %%
## 2
n_gRNA_perconstruct = 2

E_KO2_bioccp, sd_KO2_bioccp = BioCCP_RES2(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_KO2_sim, sd_KO2_sim = simulate_RES2(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 4
n_gRNA_perconstruct = 4

E_KO4_bioccp, sd_KO4_bioccp = BioCCP_RES2(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_KO4_sim, sd_KO4_sim = simulate_RES2(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)

## 6
n_gRNA_perconstruct = 6

E_KO6_bioccp, sd_KO6_bioccp = BioCCP_RES2(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_KO6_sim, sd_KO6_sim = simulate_RES2(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
## 8
n_gRNA_perconstruct = 8

E_KO8_bioccp, sd_KO8_bioccp = BioCCP_RES2(n_targets, 
                              n_gRNA_pergene, 
                              n_gRNA_perconstruct, 
                              n_gRNA_total, 
                              p_gRNA_lib, 
                              p_gRNA_act, ϵ_knockout_global)

E_KO8_sim, sd_KO8_sim = simulate_RES2(n_targets, 
                                n_gRNA_pergene, 
                                n_gRNA_perconstruct, 
                                n_gRNA_total, 
                                p_gRNA_lib, 
                                p_gRNA_act, ϵ_knockout_global; iter=500)
# Out:
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
#
# Iteration: 100 ... Calculating minimum number of plants ...
#
# Iteration: 200 ... Calculating minimum number of plants ...
#
# Iteration: 300 ... Calculating minimum number of plants ...
#
# Iteration: 400 ... Calculating minimum number of plants ...
#
# Iteration: 500 ... Calculating minimum number of plants ...
# (131.292, 35.10446385811258)

# %%
E_KO_sim = [E_KO2_sim, E_KO4_sim, E_KO6_sim,E_KO8_sim]
E_KO_bioccp = [E_KO2_bioccp, E_KO4_bioccp, E_KO6_bioccp, E_KO8_bioccp]
sd_KO_sim = [sd_KO2_sim, sd_KO4_sim, sd_KO6_sim,sd_KO8_sim]
sd_KO_bioccp = [sd_KO2_bioccp, sd_KO4_bioccp, sd_KO6_bioccp, sd_KO8_bioccp]
# Out:
# 4-element Array{Int64,1}:
#  818
#  133
#   51
#   28

# %%
plot([2, 4, 6, 8], E_KO_sim, label="Simulation", 
    title="Required experimental scale (average) 
    for complete coverage of all pairwise combinations
    ", xlabel="Kos pp", ylabel="Required experimental scale",
    ribbon = sd_KO_sim, fillalpha=.1,
    xticks = ([2, 4, 6, 8], string.([2, 4, 6, 8])),
    yticks = (100:400:10000, string.(100:400:10000)),
size = ((700,500)),
titlefont=font(11),
guidefontsize =11, guidefontfamily=101)

plot!([2, 4, 6, 8], E_KO_bioccp,  label="BioCCP",
    ribbon = sd_KO_bioccp, 
    fillalpha=.1,
)

plot!([2,4, 6,8], E_KO_sim,  label="",linestyle = :dot, linealpha = 0.5,
    seriestype = :steppre, linecolor = :black)

scatter!([2, 4,6,8], E_KO_sim,  label="",markersize = 3, markercolor = :black)
