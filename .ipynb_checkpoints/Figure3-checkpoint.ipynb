# %% [markdown]
# This notebook allows to reproduce **Figure 3** of the paper "Covering the Combinatorial Design Space of Multiplex CRISPR/Cas Experiments in Plants" by Kirsten Van Huffel, Michiel Stock, Thomas Jacobs, Tom Ruttink and Bernard De Baets.

# %% [markdown]
# #### Load packages

# %%
using Random 
using Plots  
using Distributions 
using LinearAlgebra
using Combinatorics
using BioCCP
# Out:
# (process:15620): GLib-GIO-WARNING **: 19:48:29.953: Unexpectedly, UWP app `HaukeGtze.7-ZipFileManagerUnofficial_1.2107.2.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.7-ZipFileManagerUnofficial_6bk20wvc8rfx2!zFM.exe') supports 36 extensions but has no verbs

# %% [markdown]
# #### Load BioCCP- and simulation-based framework

# %%
include("MultiplexCrisprDOE.jl");

# %% [markdown]
# #### Set seed for reproducibility

# %%
Random.seed!(1)
# Out:
# TaskLocalRNG()

# %%
include("DefaultParameters_k=2.jl");

# %% [markdown]
# - Figure 3A: Distribution of the abundances of the gRNAs in the construct library

# %%
Random.seed!(1)
gRNA_frequency_distribution(m, sd, l, u, n_gRNA_total; normalize = false, visualize=true)

# %% [markdown]
# - Figure 3B: Distribution of genome editing efficiencies of the gRNAs

# %%
Random.seed!(1)
gRNA_edit_distribution(f_act, ϵ_edit_act, ϵ_edit_inact, sd_act, n_gRNA_total; visualize = true)
