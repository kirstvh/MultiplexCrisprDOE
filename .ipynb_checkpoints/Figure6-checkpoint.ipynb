# %% [markdown]
# This notebook allows the reproduce **Figure 6** of the paper "Covering the Combinatorial Design Space of Multiplex CRISPR/Cas Experiments in Plants" by Kirsten Van Huffel, Michiel Stock, Tom Ruttink and Bernard De Baets.

# %% [markdown]
# #### Load packages

# %%
using Random 
using Plots  
using Distributions 
using LinearAlgebra
using Combinatorics
using BioCCP
# Out:
# (process:17292): GLib-GIO-WARNING **: 13:17:15.069: Unexpectedly, UWP app `HaukeGtze.7-ZipFileManagerUnofficial_1.2107.2.0_x64__6bk20wvc8rfx2' (AUMId `HaukeGtze.7-ZipFileManagerUnofficial_6bk20wvc8rfx2!zFM.exe') supports 36 extensions but has no verbs

# %% [markdown]
# #### Load BioCCP- and simulation-based framework

# %%
include("MultiplexCrisprDOE.jl");

# %% [markdown]
# #### Set seed for reproducibility

# %%
Random.seed!(1)
# Out:
# TaskLocalRNG()

# %% [markdown]
# #### Study relation between expected combinatorial coverage and given plant library size

# %%
include("DefaultParameters_k=2.jl");

# %% [markdown]
# - Figure 6A: expected combinatorial coverage w.r.t. plant library size

# %%
plant_library_sizes = 0:5:4000
expected_γₓ₂ = []
expected_γₓ₁ = []


for N in plant_library_sizes
    r = 2
    
    e_γₓ₂ = BioCCP_γₓ₂(x, 
                                         N,
                                         g, 
                                         r, 
                                         n_gRNA_total, 
                                         p_gRNA_freq, 
                                         p_gRNA_edit, ϵ_KO)
    push!(expected_γₓ₂, e_γₓ₂)
    if e_γₓ₂ < 0.95
        global N_95_γₓ₂ = N
    end
    
    r = 1
    
    e_γₓ₁ = BioCCP_γₓ₁(x, 
                                         N,
                                         g, 
                                         r, 
                                         n_gRNA_total, 
                                         p_gRNA_freq, 
                                         p_gRNA_edit, ϵ_KO)
    push!(expected_γₓ₁, e_γₓ₁)
    
    if e_γₓ₁ < 0.95
        global N_95_γₓ₁ = N
    end
    
end
 
plot(plant_library_sizes, expected_γₓ₁, label="E[γₓ₁]", color=:turquoise, linewidth=2)

plot!(plant_library_sizes, expected_γₓ₂,
label="E[γₓ₂]", title="Expected combinatorial coverage w.r.t. plant library size 
    ",
xlabel="N", ylabel="E[γₓₖ]", 
        xticks = (0:500:50000, string.(0:500:50000)),
 size=(950,350), color=:turquoise4, linewidth=2)
hline!([0.95], linestyle=:dash, color=:grey, label="E[γₓₖ] = 0.95", legend=:bottomright)

# %%
N_95_γₓ₁, N_95_γₓ₂
# Out:
# (80, 1205)

# %% [markdown]
# #### Study relation between probibility of full combinatorial coverage and given plant library size

# %% [markdown]
# - Figure 6B: probability of full combinatorial coverage w.r.t. plant library size

# %%
plant_library_sizes = 0:5:6000
Pₓ₁ = []
Pₓ₂ = []

for N in plant_library_sizes
    r = 2
    
    Pₓ₂_ = BioCCP_Pₓ₂(x, 
                            N,
                            g, 
                            r, 
                            n_gRNA_total, 
                            p_gRNA_freq, 
                            p_gRNA_edit, 
                            ϵ_KO)
    
    push!(Pₓ₂, Pₓ₂_)
    
    if Pₓ₂_ < 0.95
        global N_95_Pₓ₂ = N
    end
    
    r = 1
    
    Pₓ₁_ = BioCCP_Pₓ₁(x, 
                            N,
                            g, 
                            r, 
                            n_gRNA_total, 
                            p_gRNA_freq, 
                            p_gRNA_edit, 
                            ϵ_KO)
    
    push!(Pₓ₁, Pₓ₁_)
    
    if Pₓ₁_ < 0.95
        global N_95_Pₓ₁ = N
    end
    
end
 
plot(plant_library_sizes, Pₓ₁, label="Pₓ₁", color=:turquoise, linewidth=2)

plot!(plant_library_sizes, Pₓ₂, label="Pₓ₂", 
    title="Probability of full combinatorial coverage with respect to plant library size",
xlabel="N
    ", ylabel="
    Pₓₖ", 
        xticks = (0:500:50000, string.(0:500:50000)),
 size=(950,350), color=:turquoise4, linewidth=2)
hline!([0.95], linestyle=:dash, color=:grey, label="Pₓₖ = 0.95", legend=:bottomright)

# %%
N_95_Pₓ₁, N_95_Pₓ₂
# Out:
# (170, 3560)
